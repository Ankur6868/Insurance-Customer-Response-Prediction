# %%
# %pip install imbalanced-learn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.0/240.0 kB 4.8 MB/s eta 0:00:00
# ...

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import plotly.express as px
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.metrics import precision_score, recall_score, f1_score
from imblearn.over_sampling import RandomOverSampler
sns.set(style='whitegrid')
import pickle
import warnings
warnings.filterwarnings('ignore')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df=pd.read_csv('data.csv')

# %%
df.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381109 entries, 0 to 381108
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    381109 non-null  int64
#  1   Gender                381109 non-null  object
#  2   Age                   381109 non-null  int64
#  3   Driving_License       381109 non-null  int64
#  4   Region_Code           381109 non-null  float64
#  5   Previously_Insured    381109 non-null  int64
#  6   Vehicle_Age           381109 non-null  object
#  7   Vehicle_Damage        381109 non-null  object
#  8   Annual_Premium        381109 non-null  float64
#  9   Policy_Sales_Channel  381109 non-null  float64
#  10  Vintage               381109 non-null  int64
#  11  Response              381109 non-null  int64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 34.9+ MB

# %%
df.shape
# Out:
# (381109, 12)

# %%
df.isnull().sum()
# Out:
# id                      0
# Gender                  0
# Age                     0
# Driving_License         0
# Region_Code             0
# Previously_Insured      0
# Vehicle_Age             0
# Vehicle_Damage          0
# Annual_Premium          0
# Policy_Sales_Channel    0
# Vintage                 0
# Response                0
# dtype: int64

# %%
numerical_columns=['Age', 'Region_Code','Annual_Premium','Vintage']
categorical_columns=['Gender','Driving_License','Previously_Insured','Vehicle_Age','Vehicle_Damage','Response']

# %%
df[numerical_columns].describe()
# Out:
#                  Age    Region_Code  Annual_Premium        Vintage
# count  381109.000000  381109.000000   381109.000000  381109.000000
# mean       38.822584      26.388807    30564.389581     154.347397
# std        15.511611      13.229888    17213.155057      83.671304
# min        20.000000       0.000000     2630.000000      10.000000
# 25%        25.000000      15.000000    24405.000000      82.000000
# 50%        36.000000      28.000000    31669.000000     154.000000
# 75%        49.000000      35.000000    39400.000000     227.000000
# max        85.000000      52.000000   540165.000000     299.000000

# %%
df.describe(include = 'object')
# Out:
#         Gender Vehicle_Age Vehicle_Damage
# count   381109      381109         381109
# unique       2           3              2
# top       Male    1-2 Year            Yes
# freq    206089      200316         192413

# %%
df['Response'].value_counts()
# Out:
# Response
# 0    334399
# 1     46710
# Name: count, dtype: int64

# %%
sns.countplot(x='Response', data=df)
# Out:
# <Axes: xlabel='Response', ylabel='count'>

# %%
sns.distplot(df.Age)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.boxplot(y = 'Age', data = df,palette='Accent')
# Out:
# <Axes: ylabel='Age'>

# %%
sns.scatterplot(x=df['Age'],y=df['Annual_Premium'])
# Out:
# <Axes: xlabel='Age', ylabel='Annual_Premium'>

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      206089
# Female    175020
# Name: count, dtype: int64

# %%
sns.countplot(x='Gender',data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
df[['Gender','Response']].value_counts()
# Out:
# Gender  Response
# Male    0           177564
# Female  0           156835
# Male    1            28525
# Female  1            18185
# Name: count, dtype: int64

# %%
sns.countplot(x='Gender', hue='Response', data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
df[['Gender','Driving_License']].value_counts()
# Out:
# Gender  Driving_License
# Male    1                  205489
# Female  1                  174808
# Male    0                     600
# Female  0                     212
# Name: count, dtype: int64

# %%
sns.countplot(x='Gender', hue='Driving_License', data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
df["Previously_Insured"].value_counts()
# Out:
# Previously_Insured
# 0    206481
# 1    174628
# Name: count, dtype: int64

# %%
sns.countplot(x='Previously_Insured',data=df)
# Out:
# <Axes: xlabel='Previously_Insured', ylabel='count'>

# %%
df[["Previously_Insured","Response"]].value_counts()
# Out:
# Previously_Insured  Response
# 1                   0           174470
# 0                   0           159929
#                     1            46552
# 1                   1              158
# Name: count, dtype: int64

# %%
sns.countplot(x='Vehicle_Age',data=df)
# Out:
# <Axes: xlabel='Vehicle_Age', ylabel='count'>

# %%
df[["Vehicle_Age","Response"]].value_counts()
# Out:
# Vehicle_Age  Response
# 1-2 Year     0           165510
# < 1 Year     0           157584
# 1-2 Year     1            34806
# > 2 Years    0            11305
# < 1 Year     1             7202
# > 2 Years    1             4702
# Name: count, dtype: int64

# %%
sns.countplot(x='Vehicle_Age', hue='Response', data=df)
# Out:
# <Axes: xlabel='Vehicle_Age', ylabel='count'>

# %%
sns.countplot(x='Vehicle_Damage',data=df)
# Out:
# <Axes: xlabel='Vehicle_Damage', ylabel='count'>

# %%
df[["Vehicle_Damage","Response"]].value_counts()
# Out:
# Vehicle_Damage  Response
# No              0           187714
# Yes             0           146685
#                 1            45728
# No              1              982
# Name: count, dtype: int64

# %%
sns.countplot(x='Vehicle_Damage', hue='Response', data=df)
# Out:
# <Axes: xlabel='Vehicle_Damage', ylabel='count'>

# %%
sns.distplot(df.Annual_Premium)
# Out:
# <Axes: xlabel='Annual_Premium', ylabel='Density'>

# %%
df['Vintage'].describe()
# Out:
# count    381109.000000
# mean        154.347397
# std          83.671304
# min          10.000000
# 25%          82.000000
# 50%         154.000000
# 75%         227.000000
# max         299.000000
# Name: Vintage, dtype: float64

# %%
sns.distplot(df.Vintage)
# Out:
# <Axes: xlabel='Vintage', ylabel='Density'>

# %%
numerical_columns=['Age', 'Region_Code','Annual_Premium','Vintage']
categorical_columns=['Gender','Driving_License','Previously_Insured','Vehicle_Age','Vehicle_Damage','Response']

# %%
df.Gender.replace({'Male':1,'Female':2}, inplace=True)

# %%
df.Gender.unique()
# Out:
# array([1, 2])

# %%
df.Vehicle_Damage.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df.Vehicle_Damage.replace({'Yes':1,'No':0}, inplace=True)

# %%
df.Vehicle_Age.unique()
# Out:
# array(['> 2 Years', '1-2 Year', '< 1 Year'], dtype=object)

# %%
df.Vehicle_Age.replace({'< 1 Year':1,'1-2 Year':2,'> 2 Years':3}, inplace=True)

# %%
df.Vehicle_Age.unique()
# Out:
# array([3, 2, 1])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381109 entries, 0 to 381108
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    381109 non-null  int64
#  1   Gender                381109 non-null  int64
#  2   Age                   381109 non-null  int64
#  3   Driving_License       381109 non-null  int64
#  4   Region_Code           381109 non-null  float64
#  5   Previously_Insured    381109 non-null  int64
#  6   Vehicle_Age           381109 non-null  int64
#  7   Vehicle_Damage        381109 non-null  int64
#  8   Annual_Premium        381109 non-null  float64
#  9   Policy_Sales_Channel  381109 non-null  float64
#  10  Vintage               381109 non-null  int64
#  11  Response              381109 non-null  int64
# dtypes: float64(3), int64(9)
# memory usage: 34.9 MB

# %%
df.drop("id", inplace=True, axis=1)

# %%
df.head()
# Out:
#    Gender  Age  Driving_License  Region_Code  Previously_Insured  Vehicle_Age  \
# 0       1   44                1         28.0                   0            3
# 1       1   76                1          3.0                   0            2
# 2       1   47                1         28.0                   0            3
# 3       1   21                1         11.0                   1            1
# 4       2   29                1         41.0                   1            1
#
#    Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  Response
# 0               1         40454.0                  26.0      217         1
# 1               0         33536.0                  26.0      183         0
# 2               1         38294.0                  26.0       27         1
# 3               0         28619.0                 152.0      203         0
# 4               0         27496.0                 152.0       39         0

# %%
df.corr()['Response']
# Out:
# Gender                 -0.052440
# Age                     0.111147
# Driving_License         0.010155
# Region_Code             0.010570
# Previously_Insured     -0.341170
# Vehicle_Age             0.221874
# Vehicle_Damage          0.354400
# Annual_Premium          0.022575
# Policy_Sales_Channel   -0.139042
# Vintage                -0.001050
# Response                1.000000
# Name: Response, dtype: float64

# %%
df.corr()['Response'].plot(kind='bar')
# Out:
# <Axes: >

# %%
px.bar(df.corr()['Response'])
# Out:
# <div>                            <div id="9d6e9523-d56e-448e-ac0f-be8035ce05b7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9d6e9523-d56e-448e-ac0f-be8035ce05b7")) {                    Plotly.newPlot(                        "9d6e9523-d56e-448e-ac0f-be8035ce05b7",                        [{"alignmentgroup":"True","hovertemplate":"variable=Response\u003cbr\u003eindex=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Response","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Response","offsetgroup":"Response","orientation":"v","showlegend":true,"textposition":"auto","x":["Gender","Age","Driving_License","Region_Code","Previously_Insured","Vehicle_Age","Vehicle_Damage","Annual_Premium","Policy_Sales_Chann
# ...

# %%
trainDF = df.loc[:,['Vehicle_Damage','Previously_Insured','Vehicle_Age','Response']]

# Vehicle_Damage (35.43%)
# Previously_Insured (34.11%)
# Vehicle_Age (22.18)
trainDF
# Out:
#         Vehicle_Damage  Previously_Insured  Vehicle_Age  Response
# 0                    1                   0            3         1
# 1                    0                   0            2         0
# 2                    1                   0            3         1
# 3                    0                   1            1         0
# 4                    0                   1            1         0
# ...                ...                 ...          ...       ...
# 381104               0                   1            2         0
# 381105               0                   1            1         0
# 381106               0                   1            1         0
# 381107               1                   0            3         0
# 381108               0                   0            2         0
#
# [381109 rows x 4 columns]

# %%
X = trainDF.iloc[:,0:3]
y = trainDF.iloc[:,-1]
X
# Out:
#         Vehicle_Damage  Previously_Insured  Vehicle_Age
# 0                    1                   0            3
# 1                    0                   0            2
# 2                    1                   0            3
# 3                    0                   1            1
# 4                    0                   1            1
# ...                ...                 ...          ...
# 381104               0                   1            2
# 381105               0                   1            1
# 381106               0                   1            1
# 381107               1                   0            3
# 381108               0                   0            2
#
# [381109 rows x 3 columns]

# %%
trainDF.describe()
# Out:
#        Vehicle_Damage  Previously_Insured    Vehicle_Age       Response
# count   381109.000000       381109.000000  381109.000000  381109.000000
# mean         0.504877            0.458210       1.609616       0.122563
# std          0.499977            0.498251       0.567439       0.327936
# min          0.000000            0.000000       1.000000       0.000000
# 25%          0.000000            0.000000       1.000000       0.000000
# 50%          1.000000            0.000000       2.000000       0.000000
# 75%          1.000000            1.000000       2.000000       0.000000
# max          1.000000            1.000000       3.000000       1.000000

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (304887, 3)
# (76222, 3)
# (304887,)
# (76222,)

# %% [markdown]
# ML Models

# %%
from sklearn.linear_model import LogisticRegression
lr_clf = LogisticRegression()

lr_clf.fit(X_train,y_train)
y_pred = lr_clf.predict(X_test)
print("Accuracy Score: ",accuracy_score(y_test,y_pred))
scores = cross_val_score(lr_clf, X_train, y_train, cv=10) #CV 10 times
print("Accuracy Score with CV(Cross Validation): ",scores.mean())
# Out:
# Accuracy Score:  0.875613339980583
# Accuracy Score with CV(Cross Validation):  0.8778924651249447

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(random_state=0)

clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)
print("Accuracy Score: ",accuracy_score(y_test,y_pred))
scores = cross_val_score(clf, X_train, y_train, cv=10)
print("Accuracy Score with CV: ",scores.mean())
# Out:
# Accuracy Score:  0.875613339980583
# Accuracy Score with CV:  0.8778924651249447

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(max_depth=10, random_state=0)

clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)
print("Accuracy Score: ",accuracy_score(y_test,y_pred))
scores = cross_val_score(clf, X_train, y_train, cv=10)
print("Accuracy Score with CV: ",scores.mean())
# Out:
# Accuracy Score:  0.875613339980583
# Accuracy Score with CV:  0.8778924651249447

# %%
from sklearn.svm import LinearSVC
clf = LinearSVC(random_state=0, tol=1e-5)

clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)
print("Accuracy Score: ",accuracy_score(y_test,y_pred))
scores = cross_val_score(clf, X_train, y_train, cv=10)
print("Accuracy Score with CV: ",scores.mean())
# Out:
# Accuracy Score:  0.875613339980583
# Accuracy Score with CV:  0.8778924651249447

# %%
from sklearn.neighbors import KNeighborsClassifier
clf = KNeighborsClassifier(n_neighbors=3)

clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)
print("Accuracy Score: ",accuracy_score(y_test,y_pred))
scores = cross_val_score(clf, X_train, y_train, cv=10)
print("Accuracy Score with CV: ",scores.mean())
# Out:
# Accuracy Score:  0.7383957387630867
# Accuracy Score with CV:  0.8208419115827391

# %%
clf = RandomForestClassifier(max_depth=10, random_state=0)
clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)
print("Accuracy: ",accuracy_score(y_test,y_pred))

scores = cross_val_score(clf, X_train, y_train, cv=10)
print("Accuracy with CV: ",scores.mean())

print("Precision Score: ", precision_score(y_test, y_pred,average='macro'))
print("Recall Score: ", recall_score(y_test, y_pred,average='macro'))
print("F1 Score: ", f1_score(y_test, y_pred,average='macro'))
# Out:
# Accuracy:  0.875613339980583
# Accuracy with CV:  0.8778924651249447
# Precision Score:  0.4378066699902915
# Recall Score:  0.5
# F1 Score:  0.466841070766562

# %%
random_search = {'criterion': ['entropy', 'gini'],
               'max_depth': [2,3,4,5,6,7,10],
               'min_samples_leaf': [4, 6, 8],
               'min_samples_split': [5, 7,10],
               'n_estimators': [300]}

clf = RandomForestClassifier()
model = RandomizedSearchCV(estimator = clf, param_distributions = random_search, n_iter = 10,
                               cv = 4, verbose= 1, random_state= 101, n_jobs = -1)
model.fit(X_train,y_train)
# Out:
# Fitting 4 folds for each of 10 candidates, totalling 40 fits
# RandomizedSearchCV(cv=4, estimator=RandomForestClassifier(), n_jobs=-1,
#                    param_distributions={'criterion': ['entropy', 'gini'],
#                                         'max_depth': [2, 3, 4, 5, 6, 7, 10],
#                                         'min_samples_leaf': [4, 6, 8],
#                                         'min_samples_split': [5, 7, 10],
#                                         'n_estimators': [300]},
#                    random_state=101, verbose=1)

# %%
filename = 'rf_model.sav'
pickle.dump(model, open(filename, 'wb'))

# %%
filename = 'rf_model.sav'

# %%
rf_load = pickle.load(open(filename, 'rb'))

# %%
y_pred=model.predict(X_test)

# %%
from sklearn.metrics import f1_score, roc_auc_score,accuracy_score,confusion_matrix, precision_recall_curve, auc, roc_curve, recall_score, classification_report

# %%
print (classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.93     66741
#            1       0.00      0.00      0.00      9481
#
#     accuracy                           0.88     76222
#    macro avg       0.44      0.50      0.47     76222
# weighted avg       0.77      0.88      0.82     76222

# %%
Vehicle_Damage = 1
Previously_Insured = 0
Vehicle_Age = 1

prediction = model.predict([[Vehicle_Damage,Previously_Insured,Vehicle_Age]])
prediction
# Out:
# array([0])

# %%
Vehicle_Damage = 1
Previously_Insured = 1
Vehicle_Age = 2

prediction = model.predict([[Vehicle_Damage,Previously_Insured,Vehicle_Age]])
prediction
# Out:
# array([0])

# %%
from imblearn.under_sampling import RandomUnderSampler

rus = RandomUnderSampler(random_state=42)
X_resampled, y_resampled = rus.fit_resample(X_train, y_train)

# %%
X_train_resampled,X_test_resampled,y_train_resampled,y_test_resampled = train_test_split(X_resampled,y_resampled,test_size=0.2)

# %%
X_resampled.value_counts()
# Out:
# Vehicle_Damage  Previously_Insured  Vehicle_Age
# 1               0                   2              37009
# 0               1                   1              11732
# 1               0                   1               9565
# 0               1                   2               6703
# 1               0                   3               4984
# 0               0                   2               1748
#                                     1               1520
# 1               1                   2                716
#                                     1                475
#                                     3                  5
# 0               1                   3                  1
# Name: count, dtype: int64

# %%
y_resampled.value_counts()
# Out:
# Response
# 0    37229
# 1    37229
# Name: count, dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

clf_resampled = RandomForestClassifier(max_depth=10, random_state=0)

clf_resampled.fit(X_train_resampled, y_train_resampled)
y_pred_resampled = clf_resampled.predict(X_test_resampled)

print("Accuracy Score: ", accuracy_score(y_test_resampled, y_pred_resampled))
print("Precision Score: ", precision_score(y_test_resampled, y_pred_resampled, average='macro'))
print("Recall Score: ", recall_score(y_test_resampled, y_pred_resampled, average='macro'))
print("F1 Score: ", f1_score(y_test_resampled, y_pred_resampled, average='macro'))
print("\nClassification Report:\n", classification_report(y_test_resampled, y_pred_resampled))
# Out:
# Accuracy Score:  0.7836422240128929
# Precision Score:  0.8327368409332983
# Recall Score:  0.7829963231497774
# F1 Score:  0.7750896547255279
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.59      0.73      7421
#            1       0.71      0.98      0.82      7471
#
#     accuracy                           0.78     14892
#    macro avg       0.83      0.78      0.78     14892
# weighted avg       0.83      0.78      0.78     14892

# %%
random_search = {'criterion': ['entropy', 'gini'],
               'max_depth': [2,3,4,5,6,7,10],
               'min_samples_leaf': [4, 6, 8],
               'min_samples_split': [5, 7,10],
               'n_estimators': [300]}

clf = RandomForestClassifier()
model_resampled = RandomizedSearchCV(estimator = clf, param_distributions = random_search, n_iter = 10,
                               cv = 4, verbose= 1, random_state= 101, n_jobs = -1)
model_resampled.fit(X_train_resampled,y_train_resampled)
# Out:
# Fitting 4 folds for each of 10 candidates, totalling 40 fits
# RandomizedSearchCV(cv=4, estimator=RandomForestClassifier(), n_jobs=-1,
#                    param_distributions={'criterion': ['entropy', 'gini'],
#                                         'max_depth': [2, 3, 4, 5, 6, 7, 10],
#                                         'min_samples_leaf': [4, 6, 8],
#                                         'min_samples_split': [5, 7, 10],
#                                         'n_estimators': [300]},
#                    random_state=101, verbose=1)

# %%
filename_resampled = 'rf_model_resampled.sav'
pickle.dump(model_resampled, open(filename_resampled, 'wb'))

# %%
filename_resampled = 'rf_model_resampled.sav'

# %%
rf_load = pickle.load(open(filename_resampled, 'rb'))

# %%
Vehicle_Damage = 1
Previously_Insured = 0
Vehicle_Age = 1

prediction = model_resampled.predict([[Vehicle_Damage,Previously_Insured,Vehicle_Age]])
prediction
# Out:
# array([1])

# %%
Vehicle_Damage = 0
Previously_Insured = 0
Vehicle_Age = 2

prediction = model_resampled.predict([[Vehicle_Damage,Previously_Insured,Vehicle_Age]])
prediction
# Out:
# array([0])

# %%
y_pred_tuned_resampled = model_resampled.predict(X_test_resampled)
print (classification_report(y_test_resampled, y_pred_tuned_resampled))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.59      0.73      7421
#            1       0.71      0.98      0.82      7471
#
#     accuracy                           0.78     14892
#    macro avg       0.83      0.78      0.78     14892
# weighted avg       0.83      0.78      0.78     14892

# %% [markdown]
# ### Classification Report for Model Trained on Original Data

# %%
#  original data
model.fit(X_train, y_train)

y_pred_original = model.predict(X_test)
print(classification_report(y_test, y_pred_original))
# Out:
# Fitting 4 folds for each of 10 candidates, totalling 40 fits
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.93     66741
#            1       0.00      0.00      0.00      9481
#
#     accuracy                           0.88     76222
#    macro avg       0.44      0.50      0.47     76222
# weighted avg       0.77      0.88      0.82     76222

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, roc_auc_score
import pandas as pd

models = {
    "Logistic Regression": LogisticRegression(),
    "Decision Tree": DecisionTreeClassifier(random_state=0),
    "Random Forest": RandomForestClassifier(max_depth=10, random_state=0),
    "Linear SVC": LinearSVC(random_state=0, tol=1e-5),
    "KNeighbors Classifier": KNeighborsClassifier(n_neighbors=3)
}

# Train models on resampled training data
results = []
for name, model in models.items():
    model.fit(X_train_resampled, y_train_resampled)
    y_pred = model.predict(X_test_resampled)
    y_pred_proba = model.predict_proba(X_test_resampled)[:, 1] if hasattr(model, 'predict_proba') else None

    accuracy = accuracy_score(y_test_resampled, y_pred)
    precision = precision_score(y_test_resampled, y_pred, average='macro')
    recall = recall_score(y_test_resampled, y_pred, average='macro')
    f1 = f1_score(y_test_resampled, y_pred, average='macro')
    roc_auc = roc_auc_score(y_test_resampled, y_pred_proba) if y_pred_proba is not None else 'N/A'


    results.append({'Model': name, 'Accuracy': accuracy, 'Precision (Macro)': precision, 'Recall (Macro)': recall, 'F1-Score (Macro)': f1, 'ROC-AUC': roc_auc})


results_df = pd.DataFrame(results)
display(results_df.sort_values(by='F1-Score (Macro)', ascending=False))
# Out:
#                    Model  Accuracy  Precision (Macro)  Recall (Macro)  \
# 0    Logistic Regression  0.783642           0.832737        0.782996
# 1          Decision Tree  0.783642           0.832737        0.782996
# 2          Random Forest  0.783642           0.832737        0.782996
# 3             Linear SVC  0.783642           0.832737        0.782996
# 4  KNeighbors Classifier  0.544185           0.564583        0.545107
#
#    F1-Score (Macro)   ROC-AUC
# 0          0.775090  0.814383
# 1          0.775090  0.814377
# 2          0.775090  0.814377
# 3          0.775090       N/A
# 4          0.507507  0.739262

# %%
from sklearn.metrics import roc_auc_score
y_pred_proba_resampled = model_resampled.predict_proba(X_test_resampled)[:, 1]
roc_auc = roc_auc_score(y_test_resampled, y_pred_proba_resampled)

print(f"ROC-AUC Score for the resampled model: {roc_auc}")
# Out:
# ROC-AUC Score for the resampled model: 0.814380893819846

# %%
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt

# Calculate the false positive rate and true positive rate
fpr, tpr, thresholds = roc_curve(y_test_resampled, y_pred_proba_resampled)

# Plot the ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], 'k--', label='Random Guessing')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.grid(True)
plt.show()
